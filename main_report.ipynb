# %%
import pandas as pd
import pymysql
from sqlalchemy import create_engine
import getpass  # Para obtener la contraseña sin mostrar la entrada

# Obtener la contraseña de forma segura
password = getpass.getpass("Enter MySQL password: ")

# Configuración de la base de datos y la conexión
bd = "civitatis_airbnb"  # Nombre correcto de la base de datos
connection_string = f'mysql+pymysql://root:{password}@localhost/{bd}'
engine = create_engine(connection_string)

# Leer la tabla 'host' en un DataFrame
consulta = "SELECT * FROM host"  # Query para seleccionar toda la tabla 'host'
df_host = pd.read_sql(consulta, con=engine)

# Mostrar los primeros registros del DataFrame
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Mostrar los primeros registros del DataFrame
display(df_host.head(50))
# Out:
#       host_id                 host_name  host_since     host_location  \
# 0   382146507                    Lovely  2020-12-29     Málaga, Spain
# 1    11733642                Airgestión  2014-01-28             Spain
# 2    13967638                   Susanna  2014-04-06     Málaga, Spain
# 3     4884962  Esther, Francisco & Sara  2013-01-28  Andalusia, Spain
# 4   413971511                   Montana  2021-07-19  Andalusia, Spain
# 5   422798059            Carlos Alberto  2021-09-13     Málaga, Spain
# 6   446668777                      Rodo  2022-02-24     Málaga, Spain
# 7   126386697                    Lu&Cia  2017-04-18     Málaga, Spain
# 8   399961266                  Gestitur  2021-05-04           Unknown
# 9   428065882                     Maria  2021-10-19           Unknown
# 10   79877163                     Santi  2016-06-25  Andalusia, Spain
# 11  329266025                   Welcome  2020-01-20     Málaga, Spain
# ...
